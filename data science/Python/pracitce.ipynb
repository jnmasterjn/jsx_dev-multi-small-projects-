# %%
import numpy as np
import pandas as pd

# %%
team = pd.read_csv('sd.csv' )

# %%
team.head()
# Out:
#             Timestamp Name (Chinese + English) eg. 王大明 Ming  Class  \
# 0  1/20/2024 13:11:33                             蘇堉騰 Eason   1101
# 1   2/2/2024 20:23:19                            賴怡心/Aurora   1102
# 2   2/5/2024 23:11:19                                   董又慈    901
# 3   2/9/2024 20:32:56                              蔡念育 Neil   1101
# 4   2/4/2024 21:24:50                           曹慶彥 Michael   1101
#
#    Seat Number Student ID                        Your preferred debate topic  \
# 0            6     11i506  Natural Science: The Application of Artificial...
# 1            9     11i539  Natural Science: The Application of Artificial...
# 2           17     01I717  Natural Science: The Application of Artificial...
# 3           20     11i520  Natural Science: The Application of Artificial...
# 4           17     11i517  Social Science: The Government should set Pric...
#
# ...

# %%
team.drop(columns=["Timestamp"] )
# Out:
#   Name (Chinese + English) eg. 王大明 Ming  Class  Seat Number Student ID  \
# 0                             蘇堉騰 Eason   1101            6     11i506
# 1                            賴怡心/Aurora   1102            9     11i539
# 2                                   董又慈    901           17     01I717
# 3                              蔡念育 Neil   1101           20     11i520
# 4                           曹慶彥 Michael   1101           17     11i517
# 5                           沈芝妍 Ashley     901            4     01i704
# 6                              羅郁喜Sofia   1102           16     11i546
# 7                             戴凱鈞 Kelly    902           19     01i749
#
#                          Your preferred debate topic  \
# 0  Natural Science: The Application of Artificial...
# 1  Natural Science: The Application of Artificial...
# 2  Natural Science: The Application of Artificial...
# 3  Natural Science: The Application of Artificial...
# 4  Social Science: The Government should set Pric...
# ...

# %%
team.loc[2]
# Out:
# Timestamp                                                                                                                                                                                                                                                                                     2/5/2024 23:11:19
# Name (Chinese + English) eg. 王大明 Ming                                                                                                                                                                                                                                                                       董又慈
# Class                                                                                                                                                                                                                                                                                                       901
# ...
